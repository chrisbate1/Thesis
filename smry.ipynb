# %%
import pandas as pd, numpy as np, seaborn as sns, matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
smry = pd.read_csv('smry.csv')
smry.head()
# Out:
#    Unnamed: 0  PERMNO  days      CVaR     avRet       var       skw  \
# 0           1   10026   502  0.010957  0.000421  0.000212  1.528861
# 1           2   10028   502  0.120639  0.000658  0.002361 -0.078612
# 2           3   10032   502  0.063411  0.000460  0.000302 -0.903871
# 3           4   10044   502  0.028585 -0.000472  0.000170  0.112320
# 4           5   10065   502  0.036252  0.000086  0.000122 -3.981951
#
#         kurt            mo5
# 0  22.035602   70243.211591
# 1   7.097433   -5583.544609
# 2   9.449783  -15037.776731
# 3   4.745260     834.302348
# 4  42.924329 -227315.872192

# %%
fig = plt.figure(figsize=(10,10))
plt.scatter(smry['avRet'], smry['var'], s=smry['kurt'], edgecolors='r')

# %%
fig = plt.figure(figsize=(10, 10))
plt.scatter(smry['avRet'], smry['var'], s=smry['skw']*100, edgecolors='r')
