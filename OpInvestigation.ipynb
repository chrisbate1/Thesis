# %%
import pandas as pd 
import numpy as np 
import scipy.stats as st 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('CombOpData.csv')
data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d')
data['EXPIR_DATE'] = pd.to_datetime(data['EXPIR_DATE'], format='%Y-%m-%d')
data
# Out:
#              Date      OPTION_ID  STRIKE_PRC PUTCALLIND      ORet Ticker  \
# 0      2018-12-28  AAL12000L0.EX        1200       CALL  0.055772    AAL
# 1      2018-12-28  AAL12000X0.EX        1200        PUT -0.040961    AAL
# 2      2018-12-28  AAL14000L0.EX        1400       CALL  0.061667    AAL
# 3      2018-12-28  AAL14000X0.EX        1400        PUT -0.047041    AAL
# 4      2018-12-28  AAL16000L0.EX        1600       CALL  0.067671    AAL
# ...           ...            ...         ...        ...       ...    ...
# 130300 2020-01-07   VOD920bL0.EX          92       CALL -0.004515    VOD
# 130301 2020-01-07   VOD920bL1.EX          92       CALL  0.000000    VOD
# 130302 2020-01-07   VOD920bR1.EX          92        PUT  0.336472    VOD
# 130303 2020-01-07   VOD920bX0.EX          92        PUT  0.470004    VOD
# 130304 2020-01-07   VOD920bX1.EX          92        PUT  0.271934    VOD
#
#          CLOSE EXPIR_DATE  DTM     PDF   meanPDF    varPDF   skewPDF  \
# 0       636.00 2020-12-18  721  0.5150  0.384583  0.039016 -1.473015
# 1       143.50 2020-12-18  721  0.0100  0.194167  0.161404  1.748977
# 2       510.00 2020-12-18  721  0.5000  0.384583  0.039016 -1.473015
# 3       218.00 2020-12-18  721  0.0300  0.194167  0.161404  1.748977
# 4       405.00 2020-12-18  721  0.4750  0.384583  0.039016 -1.473015
# ...        ...        ...  ...     ...       ...       ...       ...
# 130300   55.25 2020-12-18  346  0.5625  0.487500  0.040703 -1.696954
# 130301   55.50 2021-12-17  710  2.2500  1.187500  0.515687 -0.279983
# 130302    3.50 2021-06-18  528  0.0000  0.240816  0.040590  0.031124
# 130303    2.00 2020-12-18  346  0.0000  0.171296  0.007103 -0.548891
# 130304    5.25 2021-12-17  710  0.0000  0.245238  0.038886  0.496949
#
#          kurtPDF    Price      SRet    impRet
# 0       3.541762  1754.20  0.023066  0.852199
# 1       4.123840  1754.20  0.023066  0.852199
# 2       3.541762  1754.20  0.023066  0.902833
# 3       4.123840  1754.20  0.023066  0.902833
# 4       3.541762  1754.20  0.023066  0.956475
# ...          ...      ...       ...       ...
# 130300  5.000927   146.66 -0.002860  0.674917
# 130301  2.945288   146.66 -0.002860  0.825638
# 130302  1.773082   146.66 -0.002860  0.772872
# 130303  3.289598   146.66 -0.002860  0.674917
# 130304  2.447994   146.66 -0.002860  0.825638
#
# [130305 rows x 17 columns]
